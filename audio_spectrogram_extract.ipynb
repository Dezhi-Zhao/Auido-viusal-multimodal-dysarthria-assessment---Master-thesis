# %%
# !pip install torch
# !pip install torchaudio
# Out:
# Collecting torch
#   Downloading torch-2.7.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting filelock (from torch)
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/conda/lib/python3.12/site-packages (from torch) (4.13.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from torch) (75.8.2)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.12/site-packages (from torch) (3.1.6)
# Collecting fsspec (from torch)
#   Downloading fsspec-2025.3.2-py3-none-any.whl.metadata (11 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch)
#   Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch)
#   Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch)
#   Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch)
#   Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch)
#   Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch)
#   Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch)
#   Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch)
#   Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch)
#   Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch)
#   Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.3.0 (from torch)
#   Downloading triton-3.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from jinja2->torch) (3.0.2)
# Downloading torch-2.7.0-cp312-cp312-manylinux_2_28_x86_64.whl (865.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.0/865.0 MB 80.9 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 104.0 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 73.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 153.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 217.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 94.4 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 138.0 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 253.7 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 148.0 MB/s eta 0:00:00a 0:00:01
# Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 148.4 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 141.9 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 140.6 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 149.6 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 93.5 MB/s eta 0:00:00:00:01
# Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Downloading triton-3.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (156.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 MB 143.5 MB/s eta 0:00:0000:0100:01
# Downloading sympy-1.13.3-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 173.6 MB/s eta 0:00:00
# Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading fsspec-2025.3.2-py3-none-any.whl (194 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 221.3 MB/s eta 0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 146.9 MB/s eta 0:00:00
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, triton, sympy, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, networkx, fsspec, filelock, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch
# Successfully installed filelock-3.18.0 fsspec-2025.3.2 mpmath-1.3.0 networkx-3.4.2 nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 sympy-1.13.3 torch-2.7.0 triton-3.3.0
# Collecting torchaudio
#   Downloading torchaudio-2.7.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: torch==2.7.0 in /opt/conda/lib/python3.12/site-packages (from torchaudio) (2.7.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.12/site-packages (from torch==2.7.0->torchaudio) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/conda/lib/python3.12/site-packages (from torch==2.7.0->torchaudio) (4.13.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from torch==2.7.0->torchaudio) (75.8.2)
# Requirement already satisfied: sympy>=1.13.3 in /opt/conda/lib/python3.12/site-packages (from torch==2.7.0->torchaudio) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.12/site-packages (from torch==2.7.0->torchaudio) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.12/site-packages (from torch==2.7.0->torchaudio) (3.1.6)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.12/site-packages (from torch==2.7.0->torchaudio) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /opt/conda/lib/python3.12/site-packages (from torch==2.7.0->torchaudio) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /opt/conda/lib/python3.12/site-packages (from torch==2.7.0->torchaudio) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /opt/conda/lib/python3.12/site-packages (from torch==2.7.0->torchaudio) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /opt/conda/lib/python3.12/site-packages (from torch==2.7.0->torchaudio) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /opt/conda/lib/python3.12/site-packages (from torch==2.7.0->torchaudio) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /opt/conda/lib/python3.12/site-packages (from torch==2.7.0->torchaudio) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /opt/conda/lib/python3.12/site-packages (from torch==2.7.0->torchaudio) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /opt/conda/lib/python3.12/site-packages (from torch==2.7.0->torchaudio) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /opt/conda/lib/python3.12/site-packages (from torch==2.7.0->torchaudio) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /opt/conda/lib/python3.12/site-packages (from torch==2.7.0->torchaudio) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /opt/conda/lib/python3.12/site-packages (from torch==2.7.0->torchaudio) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /opt/conda/lib/python3.12/site-packages (from torch==2.7.0->torchaudio) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /opt/conda/lib/python3.12/site-packages (from torch==2.7.0->torchaudio) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /opt/conda/lib/python3.12/site-packages (from torch==2.7.0->torchaudio) (1.11.1.6)
# Requirement already satisfied: triton==3.3.0 in /opt/conda/lib/python3.12/site-packages (from torch==2.7.0->torchaudio) (3.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy>=1.13.3->torch==2.7.0->torchaudio) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from jinja2->torch==2.7.0->torchaudio) (3.0.2)
# Downloading torchaudio-2.7.0-cp312-cp312-manylinux_2_28_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 58.5 MB/s eta 0:00:00
# Installing collected packages: torchaudio
# Successfully installed torchaudio-2.7.0

# %%
import os
import json
import torch
import torchaudio
import numpy as np

# %%
# Load and align pair (audio only)
def load_aligned_pair(wav_path, sr=16000, fixed_samples=16000, device='cuda' if torch.cuda.is_available() else 'cpu'):
    try:
        audio, sample_rate = torchaudio.load(wav_path)
        if sample_rate != sr:
            audio = torchaudio.transforms.Resample(orig_freq=sample_rate, new_freq=sr)(audio)
        if audio.shape[1] > fixed_samples:
            audio = audio[:, :fixed_samples]
        elif audio.shape[1] < fixed_samples:
            audio = torch.nn.functional.pad(audio, (0, fixed_samples - audio.shape[1]))
        return audio.to(device)
    except Exception as e:
        raise RuntimeError(f"Error loading {wav_path}: {e}")

# Audio to spectrogram
def audio_to_spectrogram(audio, sr=16000, n_fft=512, hop_length=256, n_mels=128, fmax=8000, device='cuda' if torch.cuda.is_available() else 'cpu'):
    spec_transform = torchaudio.transforms.MelSpectrogram(
        sample_rate=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels, f_max=fmax
    ).to(audio.device)
    mel = spec_transform(audio)
    mel = mel.mean(dim=0)
    mel_db = torchaudio.transforms.AmplitudeToDB(stype='power', top_db=None)(mel)
    mel_db -= mel_db.max()
    return mel_db

# Precompute spectrograms
def precompute_spectrograms(file_path='data_copy.list', output_dir='spectrograms', sr=16000, fixed_samples=16000, device='cuda' if torch.cuda.is_available() else 'cpu'):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    entries = []
    with open(file_path, 'r') as f:
        for line in f:
            if not line.strip():
                continue
            try:
                entry = json.loads(line.strip())
                wav_path = os.path.join('audio', os.path.basename(entry['wav_path']))
                video_path = os.path.join('video', os.path.splitext(os.path.basename(entry['wav_path']))[0] + '.avi')
                if os.path.exists(wav_path) and os.path.exists(video_path):
                    entries.append({
                        'key': entry['key'],
                        'wav_path': wav_path,
                        'video_path': video_path,
                        'label': int(entry['label']),
                        'Frenchay': entry['Frenchay']
                    })
            except json.JSONDecodeError:
                print(f"Skipping invalid JSON line: {line}")
                continue
    
    for idx, entry in enumerate(entries):
        try:
            audio = load_aligned_pair(entry['wav_path'], sr=sr, fixed_samples=fixed_samples, device=device)
            spec = audio_to_spectrogram(audio, sr=sr, n_fft=512, hop_length=256, n_mels=128, fmax=8000, device=device)
            np.save(os.path.join(output_dir, f'spec_{entry["key"]}.npy'), spec.cpu().numpy())
            if idx % 100 == 0:
                print(f"Precomputed {idx} spectrograms")
        except Exception as e:
            print(f"Error precomputing spectrogram for {entry['wav_path']}: {e}")
            continue
    print(f"Finished precomputing spectrograms for {len(entries)} clips")

if __name__ == "__main__":
    precompute_spectrograms()
# Out:
# Skipping invalid JSON line: {"key": "S_M_00051_G2_task1_4_S00004", "wav_path": "data/S_M_00051_G2_task1_4_S00004.wav", "label": 1, "Frenchay": 114}4{"key": "S_M_00020_G4_task1_5_S00007", "wav_path": "data/S_M_00020_G4_task1_5_S00007.wav", "label": 1, "Frenchay": 92}
# /opt/conda/lib/python3.12/site-packages/torchaudio/functional/functional.py:584: UserWarning: At least one mel filterbank has all zero values. The value for `n_mels` (128) may be set too high. Or, the value for `n_freqs` (257) may be set too low.
#   warnings.warn(
# Precomputed 0 spectrograms
# Precomputed 100 spectrograms
# Precomputed 200 spectrograms
# Precomputed 300 spectrograms
# Precomputed 400 spectrograms
# Precomputed 500 spectrograms
# Precomputed 600 spectrograms
# Precomputed 700 spectrograms
# Precomputed 800 spectrograms
# Precomputed 900 spectrograms
# Precomputed 1000 spectrograms
# Precomputed 1100 spectrograms
# Precomputed 1200 spectrograms
# Precomputed 1300 spectrograms
# Precomputed 1400 spectrograms
# Precomputed 1500 spectrograms
# Precomputed 1600 spectrograms
# Precomputed 1700 spectrograms
# Precomputed 1800 spectrograms
# Precomputed 1900 spectrograms
# Precomputed 2000 spectrograms
# Precomputed 2100 spectrograms
# Precomputed 2200 spectrograms
# Precomputed 2300 spectrograms
# Precomputed 2400 spectrograms
# Precomputed 2500 spectrograms
# Precomputed 2600 spectrograms
# Precomputed 2700 spectrograms
# Precomputed 2800 spectrograms
# Precomputed 2900 spectrograms
# Precomputed 3000 spectrograms
# Precomputed 3100 spectrograms
# Precomputed 3200 spectrograms
# Precomputed 3300 spectrograms
# Precomputed 3400 spectrograms
# Precomputed 3500 spectrograms
# Precomputed 3600 spectrograms
# Precomputed 3700 spectrograms
# Precomputed 3800 spectrograms
# Precomputed 3900 spectrograms
# Precomputed 4000 spectrograms
# Precomputed 4100 spectrograms
# Precomputed 4200 spectrograms
# Precomputed 4300 spectrograms
# Precomputed 4400 spectrograms
# Precomputed 4500 spectrograms
# Precomputed 4600 spectrograms
# Precomputed 4700 spectrograms
# Precomputed 4800 spectrograms
# Precomputed 4900 spectrograms
# Precomputed 5000 spectrograms
# Precomputed 5100 spectrograms
# Precomputed 5200 spectrograms
# Precomputed 5300 spectrograms
# Precomputed 5400 spectrograms
# Precomputed 5500 spectrograms
# Precomputed 5600 spectrograms
# Precomputed 5700 spectrograms
# Precomputed 5800 spectrograms
# Precomputed 5900 spectrograms
# Precomputed 6000 spectrograms
# Precomputed 6100 spectrograms
# Precomputed 6200 spectrograms
# Precomputed 6300 spectrograms
# Precomputed 6400 spectrograms
# Precomputed 6500 spectrograms
# Precomputed 6600 spectrograms
# Precomputed 6700 spectrograms
# Precomputed 6800 spectrograms
# Precomputed 6900 spectrograms
# Precomputed 7000 spectrograms
# Precomputed 7100 spectrograms
# Precomputed 7200 spectrograms
# Precomputed 7300 spectrograms
# Precomputed 7400 spectrograms
# Precomputed 7500 spectrograms
# Precomputed 7600 spectrograms
# Precomputed 7700 spectrograms
# Precomputed 7800 spectrograms
# Precomputed 7900 spectrograms
# Precomputed 8000 spectrograms
# Precomputed 8100 spectrograms
# Precomputed 8200 spectrograms
# Precomputed 8300 spectrograms
# Precomputed 8400 spectrograms
# Precomputed 8500 spectrograms
# Precomputed 8600 spectrograms
# Precomputed 8700 spectrograms
# Precomputed 8800 spectrograms
# Precomputed 8900 spectrograms
# Precomputed 9000 spectrograms
# Precomputed 9100 spectrograms
# Precomputed 9200 spectrograms
# Precomputed 9300 spectrograms
# Precomputed 9400 spectrograms
# Precomputed 9500 spectrograms
# Precomputed 9600 spectrograms
# Precomputed 9700 spectrograms
# Precomputed 9800 spectrograms
# Precomputed 9900 spectrograms
# Precomputed 10000 spectrograms
# Precomputed 10100 spectrograms
# Precomputed 10200 spectrograms
# Precomputed 10300 spectrograms
# Precomputed 10400 spectrograms
# Precomputed 10500 spectrograms
# Precomputed 10600 spectrograms
# Precomputed 10700 spectrograms
# Precomputed 10800 spectrograms
# Precomputed 10900 spectrograms
# Precomputed 11000 spectrograms
# Precomputed 11100 spectrograms
# Precomputed 11200 spectrograms
# Precomputed 11300 spectrograms
# Precomputed 11400 spectrograms
# Precomputed 11500 spectrograms
# Precomputed 11600 spectrograms
# Precomputed 11700 spectrograms
# Precomputed 11800 spectrograms
# Precomputed 11900 spectrograms
# Precomputed 12000 spectrograms
# Precomputed 12100 spectrograms
# Precomputed 12200 spectrograms
# Precomputed 12300 spectrograms
# Precomputed 12400 spectrograms
# Precomputed 12500 spectrograms
# Precomputed 12600 spectrograms
# Precomputed 12700 spectrograms
# Precomputed 12800 spectrograms
# Precomputed 12900 spectrograms
# Precomputed 13000 spectrograms
# Precomputed 13100 spectrograms
# Precomputed 13200 spectrograms
# Precomputed 13300 spectrograms
# Precomputed 13400 spectrograms
# Precomputed 13500 spectrograms
# Precomputed 13600 spectrograms
# Precomputed 13700 spectrograms
# Precomputed 13800 spectrograms
# Precomputed 13900 spectrograms
# Precomputed 14000 spectrograms
# Precomputed 14100 spectrograms
# Precomputed 14200 spectrograms
# Precomputed 14300 spectrograms
# Precomputed 14400 spectrograms
# Precomputed 14500 spectrograms
# Precomputed 14600 spectrograms
# Precomputed 14700 spectrograms
# Precomputed 14800 spectrograms
# Precomputed 14900 spectrograms
# Precomputed 15000 spectrograms
# Precomputed 15100 spectrograms
# Precomputed 15200 spectrograms
# Precomputed 15300 spectrograms
# Precomputed 15400 spectrograms
# Precomputed 15500 spectrograms
# Precomputed 15600 spectrograms
# Precomputed 15700 spectrograms
# Precomputed 15800 spectrograms
# Precomputed 15900 spectrograms
# Precomputed 16000 spectrograms
# Precomputed 16100 spectrograms
# Precomputed 16200 spectrograms
# Precomputed 16300 spectrograms
# Precomputed 16400 spectrograms
# Precomputed 16500 spectrograms
# Precomputed 16600 spectrograms
# Precomputed 16700 spectrograms
# Precomputed 16800 spectrograms
# Precomputed 16900 spectrograms
# Precomputed 17000 spectrograms
# Precomputed 17100 spectrograms
# Precomputed 17200 spectrograms
# Precomputed 17300 spectrograms
# Precomputed 17400 spectrograms
# Precomputed 17500 spectrograms
# Precomputed 17600 spectrograms
# Precomputed 17700 spectrograms
# Precomputed 17800 spectrograms
# Precomputed 17900 spectrograms
# Precomputed 18000 spectrograms
# Precomputed 18100 spectrograms
# Precomputed 18200 spectrograms
# Precomputed 18300 spectrograms
# Precomputed 18400 spectrograms
# Precomputed 18500 spectrograms
# Precomputed 18600 spectrograms
# Precomputed 18700 spectrograms
# Precomputed 18800 spectrograms
# Precomputed 18900 spectrograms
# Precomputed 19000 spectrograms
# Precomputed 19100 spectrograms
# Precomputed 19200 spectrograms
# Precomputed 19300 spectrograms
# Precomputed 19400 spectrograms
# Precomputed 19500 spectrograms
# Precomputed 19600 spectrograms
# Precomputed 19700 spectrograms
# Precomputed 19800 spectrograms
# Precomputed 19900 spectrograms
# Precomputed 20000 spectrograms
# Precomputed 20100 spectrograms
# Precomputed 20200 spectrograms
# Precomputed 20300 spectrograms
# Precomputed 20400 spectrograms
# Precomputed 20500 spectrograms
# Precomputed 20600 spectrograms
# Precomputed 20700 spectrograms
# Precomputed 20800 spectrograms
# Precomputed 20900 spectrograms
# Precomputed 21000 spectrograms
# Precomputed 21100 spectrograms
# Precomputed 21200 spectrograms
# Precomputed 21300 spectrograms
# Precomputed 21400 spectrograms
# Precomputed 21500 spectrograms
# Precomputed 21600 spectrograms
# Precomputed 21700 spectrograms
# Precomputed 21800 spectrograms
# Precomputed 21900 spectrograms
# Precomputed 22000 spectrograms
# Precomputed 22100 spectrograms
# Precomputed 22200 spectrograms
# Precomputed 22300 spectrograms
# Precomputed 22400 spectrograms
# Precomputed 22500 spectrograms
# Precomputed 22600 spectrograms
# Precomputed 22700 spectrograms
# Precomputed 22800 spectrograms
# Precomputed 22900 spectrograms
# Precomputed 23000 spectrograms
# Precomputed 23100 spectrograms
# Precomputed 23200 spectrograms
# Precomputed 23300 spectrograms
# Precomputed 23400 spectrograms
# Precomputed 23500 spectrograms
# Precomputed 23600 spectrograms
# Precomputed 23700 spectrograms
# Precomputed 23800 spectrograms
# Precomputed 23900 spectrograms
# Precomputed 24000 spectrograms
# Precomputed 24100 spectrograms
# Precomputed 24200 spectrograms
# Precomputed 24300 spectrograms
# Precomputed 24400 spectrograms
# Precomputed 24500 spectrograms
# Precomputed 24600 spectrograms
# Precomputed 24700 spectrograms
# Precomputed 24800 spectrograms
# Precomputed 24900 spectrograms
# Precomputed 25000 spectrograms
# Precomputed 25100 spectrograms
# Precomputed 25200 spectrograms
# Precomputed 25300 spectrograms
# Precomputed 25400 spectrograms
# Precomputed 25500 spectrograms
# Precomputed 25600 spectrograms
# Precomputed 25700 spectrograms
# Precomputed 25800 spectrograms
# Precomputed 25900 spectrograms
# Precomputed 26000 spectrograms
# Precomputed 26100 spectrograms
# Precomputed 26200 spectrograms
# Precomputed 26300 spectrograms
# Precomputed 26400 spectrograms
# Precomputed 26500 spectrograms
# Precomputed 26600 spectrograms
# Precomputed 26700 spectrograms
# Precomputed 26800 spectrograms
# Precomputed 26900 spectrograms
# Precomputed 27000 spectrograms
# Precomputed 27100 spectrograms
# Precomputed 27200 spectrograms
# Precomputed 27300 spectrograms
# Precomputed 27400 spectrograms
# Precomputed 27500 spectrograms
# Precomputed 27600 spectrograms
# Precomputed 27700 spectrograms
# Precomputed 27800 spectrograms
# Precomputed 27900 spectrograms
# Precomputed 28000 spectrograms
# Precomputed 28100 spectrograms
# Precomputed 28200 spectrograms
# Precomputed 28300 spectrograms
# Precomputed 28400 spectrograms
# Precomputed 28500 spectrograms
# Precomputed 28600 spectrograms
# Precomputed 28700 spectrograms
# Precomputed 28800 spectrograms
# Precomputed 28900 spectrograms
# Precomputed 29000 spectrograms
# Precomputed 29100 spectrograms
# Precomputed 29200 spectrograms
# Precomputed 29300 spectrograms
# Precomputed 29400 spectrograms
# Precomputed 29500 spectrograms
# Precomputed 29600 spectrograms
# Precomputed 29700 spectrograms
# Precomputed 29800 spectrograms
# Precomputed 29900 spectrograms
# Precomputed 30000 spectrograms
# Precomputed 30100 spectrograms
# Precomputed 30200 spectrograms
# Precomputed 30300 spectrograms
# Precomputed 30400 spectrograms
# Precomputed 30500 spectrograms
# Precomputed 30600 spectrograms
# Precomputed 30700 spectrograms
# Precomputed 30800 spectrograms
# Precomputed 30900 spectrograms
# Precomputed 31000 spectrograms
# Precomputed 31100 spectrograms
# Precomputed 31200 spectrograms
# Precomputed 31300 spectrograms
# Precomputed 31400 spectrograms
# Precomputed 31500 spectrograms
# Precomputed 31600 spectrograms
# Precomputed 31700 spectrograms
# Precomputed 31800 spectrograms
# Precomputed 31900 spectrograms
# Precomputed 32000 spectrograms
# Precomputed 32100 spectrograms
# Precomputed 32200 spectrograms
# Precomputed 32300 spectrograms
# Precomputed 32400 spectrograms
# Precomputed 32500 spectrograms
# Precomputed 32600 spectrograms
# Precomputed 32700 spectrograms
# Precomputed 32800 spectrograms
# Precomputed 32900 spectrograms
# Precomputed 33000 spectrograms
# Precomputed 33100 spectrograms
# Precomputed 33200 spectrograms
# Precomputed 33300 spectrograms
# Precomputed 33400 spectrograms
# Precomputed 33500 spectrograms
# Precomputed 33600 spectrograms
# Precomputed 33700 spectrograms
# Precomputed 33800 spectrograms
# Precomputed 33900 spectrograms
# Precomputed 34000 spectrograms
# Precomputed 34100 spectrograms
# Precomputed 34200 spectrograms
# Precomputed 34300 spectrograms
# Precomputed 34400 spectrograms
# Precomputed 34500 spectrograms
# Precomputed 34600 spectrograms
# Precomputed 34700 spectrograms
# Precomputed 34800 spectrograms
# Precomputed 34900 spectrograms
# Precomputed 35000 spectrograms
# Precomputed 35100 spectrograms
# Precomputed 35200 spectrograms
# Precomputed 35300 spectrograms
# Precomputed 35400 spectrograms
# Precomputed 35500 spectrograms
# Precomputed 35600 spectrograms
# Precomputed 35700 spectrograms
# Precomputed 35800 spectrograms
# Precomputed 35900 spectrograms
# Precomputed 36000 spectrograms
# Precomputed 36100 spectrograms
# Precomputed 36200 spectrograms
# Precomputed 36300 spectrograms
# Precomputed 36400 spectrograms
# Precomputed 36500 spectrograms
# Precomputed 36600 spectrograms
# Precomputed 36700 spectrograms
# Precomputed 36800 spectrograms
# Precomputed 36900 spectrograms
# Precomputed 37000 spectrograms
# Precomputed 37100 spectrograms
# Precomputed 37200 spectrograms
# Precomputed 37300 spectrograms
# Precomputed 37400 spectrograms
# Precomputed 37500 spectrograms
# Precomputed 37600 spectrograms
# Precomputed 37700 spectrograms
# Precomputed 37800 spectrograms
# Precomputed 37900 spectrograms
# Precomputed 38000 spectrograms
# Precomputed 38100 spectrograms
# Precomputed 38200 spectrograms
# Precomputed 38300 spectrograms
# Precomputed 38400 spectrograms
# Precomputed 38500 spectrograms
# Precomputed 38600 spectrograms
# Precomputed 38700 spectrograms
# Precomputed 38800 spectrograms
# Precomputed 38900 spectrograms
# Precomputed 39000 spectrograms
# Precomputed 39100 spectrograms
# Precomputed 39200 spectrograms
# Precomputed 39300 spectrograms
# Precomputed 39400 spectrograms
# Precomputed 39500 spectrograms
# Precomputed 39600 spectrograms
# Precomputed 39700 spectrograms
# Precomputed 39800 spectrograms
# Precomputed 39900 spectrograms
# Precomputed 40000 spectrograms
# Precomputed 40100 spectrograms
# Precomputed 40200 spectrograms
# Precomputed 40300 spectrograms
# Precomputed 40400 spectrograms
# Precomputed 40500 spectrograms
# Precomputed 40600 spectrograms
# Precomputed 40700 spectrograms
# Precomputed 40800 spectrograms
# Precomputed 40900 spectrograms
# Precomputed 41000 spectrograms
# Precomputed 41100 spectrograms
# Precomputed 41200 spectrograms
# Precomputed 41300 spectrograms
# Precomputed 41400 spectrograms
# Precomputed 41500 spectrograms
# Precomputed 41600 spectrograms
# Precomputed 41700 spectrograms
# Precomputed 41800 spectrograms
# Precomputed 41900 spectrograms
# Precomputed 42000 spectrograms
# Precomputed 42100 spectrograms
# Precomputed 42200 spectrograms
# Precomputed 42300 spectrograms
# Precomputed 42400 spectrograms
# Precomputed 42500 spectrograms
# Precomputed 42600 spectrograms
# Precomputed 42700 spectrograms
# Precomputed 42800 spectrograms
# Precomputed 42900 spectrograms
# Precomputed 43000 spectrograms
# Precomputed 43100 spectrograms
# Precomputed 43200 spectrograms
# Precomputed 43300 spectrograms
# Precomputed 43400 spectrograms
# Precomputed 43500 spectrograms
# Precomputed 43600 spectrograms
# Precomputed 43700 spectrograms
# Precomputed 43800 spectrograms
# Precomputed 43900 spectrograms
# Precomputed 44000 spectrograms
# Precomputed 44100 spectrograms
# Precomputed 44200 spectrograms
# Precomputed 44300 spectrograms
# Precomputed 44400 spectrograms
# Precomputed 44500 spectrograms
# Precomputed 44600 spectrograms
# Precomputed 44700 spectrograms
# Precomputed 44800 spectrograms
# Precomputed 44900 spectrograms
# Precomputed 45000 spectrograms
# Precomputed 45100 spectrograms
# Precomputed 45200 spectrograms
# Precomputed 45300 spectrograms
# Precomputed 45400 spectrograms
# Precomputed 45500 spectrograms
# Precomputed 45600 spectrograms
# Precomputed 45700 spectrograms
# Precomputed 45800 spectrograms
# Precomputed 45900 spectrograms
# Precomputed 46000 spectrograms
# Precomputed 46100 spectrograms
# Precomputed 46200 spectrograms
# Precomputed 46300 spectrograms
# Precomputed 46400 spectrograms
# Precomputed 46500 spectrograms
# Precomputed 46600 spectrograms
# Precomputed 46700 spectrograms
# Precomputed 46800 spectrograms
# Precomputed 46900 spectrograms
# Precomputed 47000 spectrograms
# Precomputed 47100 spectrograms
# Precomputed 47200 spectrograms
# Precomputed 47300 spectrograms
# Precomputed 47400 spectrograms
# Precomputed 47500 spectrograms
# Precomputed 47600 spectrograms
# Precomputed 47700 spectrograms
# Precomputed 47800 spectrograms
# Precomputed 47900 spectrograms
# Precomputed 48000 spectrograms
# Precomputed 48100 spectrograms
# Precomputed 48200 spectrograms
# Precomputed 48300 spectrograms
# Precomputed 48400 spectrograms
# Precomputed 48500 spectrograms
# Precomputed 48600 spectrograms
# Precomputed 48700 spectrograms
# Precomputed 48800 spectrograms
# Precomputed 48900 spectrograms
# Precomputed 49000 spectrograms
# Precomputed 49100 spectrograms
# Precomputed 49200 spectrograms
# Precomputed 49300 spectrograms
# Precomputed 49400 spectrograms
# Precomputed 49500 spectrograms
# Precomputed 49600 spectrograms
# Precomputed 49700 spectrograms
# Precomputed 49800 spectrograms
# Precomputed 49900 spectrograms
# Precomputed 50000 spectrograms
# Precomputed 50100 spectrograms
# Precomputed 50200 spectrograms
# Precomputed 50300 spectrograms
# Precomputed 50400 spectrograms
# Precomputed 50500 spectrograms
# Precomputed 50600 spectrograms
# Precomputed 50700 spectrograms
# Precomputed 50800 spectrograms
# Precomputed 50900 spectrograms
# Precomputed 51000 spectrograms
# Precomputed 51100 spectrograms
# Precomputed 51200 spectrograms
# Precomputed 51300 spectrograms
# Precomputed 51400 spectrograms
# Precomputed 51500 spectrograms
# Precomputed 51600 spectrograms
# Precomputed 51700 spectrograms
# Precomputed 51800 spectrograms
# Precomputed 51900 spectrograms
# Precomputed 52000 spectrograms
# Precomputed 52100 spectrograms
# Precomputed 52200 spectrograms
# Precomputed 52300 spectrograms
# Precomputed 52400 spectrograms
# Precomputed 52500 spectrograms
# Precomputed 52600 spectrograms
# Precomputed 52700 spectrograms
# Precomputed 52800 spectrograms
# Precomputed 52900 spectrograms
# Precomputed 53000 spectrograms
# Precomputed 53100 spectrograms
# Precomputed 53200 spectrograms
# Precomputed 53300 spectrograms
# Precomputed 53400 spectrograms
# Precomputed 53500 spectrograms
# Precomputed 53600 spectrograms
# Precomputed 53700 spectrograms
# Precomputed 53800 spectrograms
# Precomputed 53900 spectrograms
# Precomputed 54000 spectrograms
# Precomputed 54100 spectrograms
# Precomputed 54200 spectrograms
# Precomputed 54300 spectrograms
# Precomputed 54400 spectrograms
# Precomputed 54500 spectrograms
# Precomputed 54600 spectrograms
# Precomputed 54700 spectrograms
# Precomputed 54800 spectrograms
# Precomputed 54900 spectrograms
# Precomputed 55000 spectrograms
# Precomputed 55100 spectrograms
# Precomputed 55200 spectrograms
# Precomputed 55300 spectrograms
# Precomputed 55400 spectrograms
# Precomputed 55500 spectrograms
# Precomputed 55600 spectrograms
# Precomputed 55700 spectrograms
# Precomputed 55800 spectrograms
# Precomputed 55900 spectrograms
# Precomputed 56000 spectrograms
# Precomputed 56100 spectrograms
# Precomputed 56200 spectrograms
# Precomputed 56300 spectrograms
# Precomputed 56400 spectrograms
# Precomputed 56500 spectrograms
# Precomputed 56600 spectrograms
# Precomputed 56700 spectrograms
# Precomputed 56800 spectrograms
# Precomputed 56900 spectrograms
# Precomputed 57000 spectrograms
# Precomputed 57100 spectrograms
# Precomputed 57200 spectrograms
# Precomputed 57300 spectrograms
# Precomputed 57400 spectrograms
# Precomputed 57500 spectrograms
# Precomputed 57600 spectrograms
# Precomputed 57700 spectrograms
# Precomputed 57800 spectrograms
# Precomputed 57900 spectrograms
# Precomputed 58000 spectrograms
# Precomputed 58100 spectrograms
# Precomputed 58200 spectrograms
# Precomputed 58300 spectrograms
# Precomputed 58400 spectrograms
# Precomputed 58500 spectrograms
# Precomputed 58600 spectrograms
# Precomputed 58700 spectrograms
# Precomputed 58800 spectrograms
# Precomputed 58900 spectrograms
# Precomputed 59000 spectrograms
# Precomputed 59100 spectrograms
# Precomputed 59200 spectrograms
# Precomputed 59300 spectrograms
# Precomputed 59400 spectrograms
# Precomputed 59500 spectrograms
# Precomputed 59600 spectrograms
# Precomputed 59700 spectrograms
# Precomputed 59800 spectrograms
# Precomputed 59900 spectrograms
# Precomputed 60000 spectrograms
# Precomputed 60100 spectrograms
# Precomputed 60200 spectrograms
# Precomputed 60300 spectrograms
# Precomputed 60400 spectrograms
# Finished precomputing spectrograms for 60476 clips
